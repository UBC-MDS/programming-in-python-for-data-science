# %%
import pandas as pd
import sys
df = pd.read_csv('../data/cereal.csv', index_col=0)
df.head(15)
pd.options.display.max_rows = 10

# %%
df.iloc[5:11]
# Out:
#                         mfr  type  calories  protein  fat  sodium  fiber  \
# name
# Apple Cinnamon Cheerios   G  Cold       110        2    2     180    1.5
# Apple Jacks               K  Cold       110        2    0     125    1.0
# Basic 4                   G  Cold       130        3    2     210    2.0
# Bran Chex                 R  Cold        90        2    1     200    4.0
# Bran Flakes               P  Cold        90        3    0     210    5.0
# Cap'n'Crunch              Q  Cold       120        1    2     220    0.0
#
#                          carbo  sugars  potass  vitamins  shelf  weight  cups  \
# name
# Apple Cinnamon Cheerios   10.5      10      70        25      1    1.00  0.75
# Apple Jacks               11.0      14      30        25      2    1.00  1.00
# Basic 4                   18.0       8     100        25      3    1.33  0.75
# Bran Chex                 15.0       6     125        25      1    1.00  0.67
# Bran Flakes               13.0       5     190        25      3    1.00  0.67
# Cap'n'Crunch              12.0      12      35        25      2    1.00  0.75
#
#                             rating
# name
# Apple Cinnamon Cheerios  29.509541
# Apple Jacks              33.174094
# Basic 4                  37.038562
# Bran Chex                49.120253
# Bran Flakes              53.313813
# Cap'n'Crunch             18.042851

# %%
df.loc[ : , "calories": "fiber"]
# Out:
#                            calories  protein  fat  sodium  fiber
# name
# 100% Bran                        70        4    1     130   10.0
# 100% Natural Bran               120        3    5      15    2.0
# All-Bran                         70        4    1     260    9.0
# All-Bran with Extra Fiber        50        4    0     140   14.0
# Almond Delight                  110        2    2     200    1.0
# ...                             ...      ...  ...     ...    ...
# Triples                         110        2    1     250    0.0
# Trix                            110        1    1     140    0.0
# Wheat Chex                      100        3    1     230    3.0
# Wheaties                        100        3    1     200    3.0
# Wheaties Honey Gold             110        2    1     200    1.0
#
# [77 rows x 5 columns]

# %%
df.loc[["Wheaties", "Trix", "Clusters"], ['type', 'rating', 'sugars']]
# Out:
#           type     rating  sugars
# name
# Wheaties  Cold  51.592193       3
# Trix      Cold  27.753301      12
# Clusters  Cold  40.400208       7

# %%
df.iloc[]

# %%
print(df.shape)

# %%
df.length

# %%
pandas_spec = importlib.util.find_spec("pandas") 
found = pandas_spec is not None

# %%
import importlib

# %%
found

# %%
pandas_spec

# %%
if "pandas" not in sys.modules:
    print('You have not imported the {} module'.format("pandas"))
