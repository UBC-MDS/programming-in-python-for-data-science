# %%
import pandas as pd

df = pd.read_csv('../data/canucks.csv')
df
# Out:
#                  Player  No.  Age  Height  Weight       Country  Position  \
# 0         Justin Bailey   38   24   193.0     214  United States  Forward
# 1            Jay Beagle   83   34   191.0     210         Canada  Forward
# 2           Jordie Benn    4   32   188.0     199         Canada  Defense
# 3   Guillaume Brisebois   56   22   188.0     175         Canada  Defense
# 4        Thatcher Demko   35   24   193.0     192  United States   Goalie
# 5       Alexander Edler   23   33   191.0     212         Swedan  Defense
# 6         Loui Eriksson   21   34   188.0     179         Swedan  Forward
# 7         Adam Gaudette   88   23   185.0     184  United States  Forward
# 8         Bo Horvat (C)   53   24   183.0     215         Canada  Forward
# 9          Quinn Hughes   43   20   178.0     175  United States  Defense
# 10         Zack MacEwen   71   23   191.0     205         Canada  Forward
# 11      Jacob Markstrom   25   30   198.0     206         Swedan   Goalie
# ...

# %%
list(df.columns)
# Out:
# ['Player',
#  'No.',
#  'Age',
#  'Height',
#  'Weight',
#  'Country ',
#  'Position',
#  'Experience',
#  'Birth Date',
#  'Salary']

# %%
df.head(2)
# Out:
#       candy bar  chocolate  peanuts  caramel  nougat  cookie_wafer_rice  \
# 0   CoffeeCrisp          1        0        0       0                  1
# 1  Butterfinger          1        1        1       0                  0
#
#    coconut  white_chocolate  multi available_canada_america
# 0        0                0      0                   Canada
# 1        0                0      0                  America

# %%
print(df.shape)
# Out:
# (22, 10)

# %%
df.length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6c0e831f20c8> in <module>
# ----> 1 df.length
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'length'
