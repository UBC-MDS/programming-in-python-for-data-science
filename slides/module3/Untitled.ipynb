# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)
df
# Out:
#                                       name mfr  type  calories  protein  fat  \
# 0                                100% Bran   N  Cold        70        4    1
# 1                        100% Natural Bran   Q  Cold       120        3    5
# 2                                 All-Bran   K  Cold        70        4    1
# 3                All-Bran with Extra Fiber   K  Cold        50        4    0
# 4                           Almond Delight   R  Cold       110        2    2
# 5                  Apple Cinnamon Cheerios   G  Cold       110        2    2
# 6                              Apple Jacks   K  Cold       110        2    0
# 7                                  Basic 4   G  Cold       130        3    2
# 8                                Bran Chex   R  Cold        90        2    1
# 9                              Bran Flakes   P  Cold        90        3    0
# 10                            Cap'n'Crunch   Q  Cold       120        1    2
# ...

# %%
df = pd.read_csv('candybars.csv')
df.set_index(['caramel', 'name']).sort_index()
# Out:
#                                    weight  chocolate  peanuts  nougat  \
# caramel name
# 0       3 Musketeers                   54          1        0       1
#         Aero                           42          1        0       0
#         Almond Joy                     46          1        0       0
#         Coffee Crisp                   50          1        0       0
#         Cookies and Cream              43          0        0       0
#         Crunchie                       26          1        0       0
#         Glosettes                      50          1        0       0
#         Kinder Surprise                20          1        0       0
#         KitKat                         45          1        0       0
#         M & M                          48          1        1       0
#         Reeses Peanutbutter Cups       43          1        1       0
#         Smarties                       45          1        0       0
# ...
