# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/cereal.csv', index_col=0)

# %%
df
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cold        70        4    1     130   10.0
# 100% Natural Bran           Q  Cold       120        3    5      15    2.0
# All-Bran                    K  Cold        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# Almond Delight              R  Cold       110        2    2     200    1.0
# ...                        ..   ...       ...      ...  ...     ...    ...
# Triples                     G  Cold       110        2    1     250    0.0
# Trix                        G  Cold       110        1    1     140    0.0
# Wheat Chex                  R  Cold       100        3    1     230    3.0
# Wheaties                    G  Cold       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cold       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8       1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843
# ...                         ...        ...
# Triples                    0.75  39.106174
# Trix                       1.00  27.753301
# Wheat Chex                 0.67  49.787445
# Wheaties                   1.00  51.592193
# Wheaties Honey Gold        0.75  36.187559
#
# [77 rows x 15 columns]

# %%
df = pd.read_csv('../../data/candybars.csv', index_col=0)

# %%
df.to_csv("candybars-sc.csv",sep=";")

# %%
df = pd.read_csv('../../data/cereal.csv', index_col=0)

# %%
df[df['mfr'] == "Q"]
# Out:
#                    mfr  type  calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Natural Bran    Q  Cold       120        3    5      15    2.0    8.0
# Cap'n'Crunch         Q  Cold       120        1    2     220    0.0   12.0
# Honey Graham Ohs     Q  Cold       120        1    2     220    1.0   12.0
# Life                 Q  Cold       100        4    2     150    2.0   12.0
# Puffed Rice          Q  Cold        50        1    0       0    0.0   13.0
# Puffed Wheat         Q  Cold        50        2    0       0    1.0   10.0
# Quaker Oat Squares   Q  Cold       100        4    1     135    2.0   14.0
# Quaker Oatmeal       Q   Hot       100        5    2       0    2.7    1.0
#
#                     sugars  potass  vitamins  shelf  weight  cups     rating
# name
# 100% Natural Bran        8     135         0      3     1.0  1.00  33.983679
# Cap'n'Crunch            12      35        25      2     1.0  0.75  18.042851
# Honey Graham Ohs        11      45        25      2     1.0  1.00  21.871292
# Life                     6      95        25      2     1.0  0.67  45.328074
# Puffed Rice              0      15         0      3     0.5  1.00  60.756112
# Puffed Wheat             0      50         0      3     0.5  1.00  63.005645
# Quaker Oat Squares       6     110        25      3     1.0  0.50  49.511874
# Quaker Oatmeal           1     110         0      1     1.0  0.67  50.828392

# %%
dfa = df[(df['mfr'] == "N") | (df['mfr'] == "Q")].loc[:,['mfr', 'rating']]
dfa
# Out:
#                           mfr     rating
# name
# 100% Bran                   N  68.402973
# 100% Natural Bran           Q  33.983679
# Cap'n'Crunch                Q  18.042851
# Cream of Wheat (Quick)      N  64.533816
# Honey Graham Ohs            Q  21.871292
# Life                        Q  45.328074
# Puffed Rice                 Q  60.756112
# Puffed Wheat                Q  63.005645
# Quaker Oat Squares          Q  49.511874
# Quaker Oatmeal              Q  50.828392
# Shredded Wheat              N  68.235885
# Shredded Wheat 'n'Bran      N  74.472949
# Shredded Wheat spoon size   N  72.801787
# Strawberry Fruit Wheats     N  59.363993

# %%
dfa[dfa['mfr'] == "N"]
# Out:
#                           mfr     rating
# name
# 100% Bran                   N  68.402973
# Cream of Wheat (Quick)      N  64.533816
# Shredded Wheat              N  68.235885
# Shredded Wheat 'n'Bran      N  74.472949
# Shredded Wheat spoon size   N  72.801787
# Strawberry Fruit Wheats     N  59.363993

# %%
times_six = lambda x: x * 6

# %%
df = pd.read_csv('../../data/pokemon.csv', index_col=0)

# %%
df.to_csv("pokemon-text.txt", sep=";")

# %%
pokemon = pd.read_csv('../../data/pokemon.csv', index_col=0)

# %%
mighty_pokemon = pokemon[(pokemon['defense'] > 100) & (pokemon['attack'] > 100)]

# %%
mighty_pokemon['type'].value_counts().plot.bar()

# %%
mighty_pokemon.shape
# Out:
# (53, 11)

# %%
mighty_pokemon['type'].value_counts()
# Out:
# rock       8
# bug        8
# water      7
# steel      7
# grass      6
# dragon     5
# ground     5
# psychic    3
# normal     2
# ice        1
# fire       1
# Name: type, dtype: int64

# %%
pokemon
# Out:
#             deck_no  attack  defense  sp_attack  sp_defense  speed  \
# name
# Bulbasaur         1      49       49         65          65     45
# Ivysaur           2      62       63         80          80     60
# Venusaur          3     100      123        122         120     80
# Charmander        4      52       43         60          50     65
# Charmeleon        5      64       58         80          65     80
# ...             ...     ...      ...        ...         ...    ...
# Celesteela      797     101      103        107         101     61
# Kartana         798     181      131         59          31    109
# Guzzlord        799     101       53         97          53     43
# Necrozma        800     107      101        127          89     79
# Magearna        801      95      115        130         115     65
#
#             capture_rt  total_bs     type  gen  legendary
# name
# Bulbasaur           45       318    grass    1          0
# Ivysaur             45       405    grass    1          0
# Venusaur            45       625    grass    1          0
# Charmander          45       309     fire    1          0
# Charmeleon          45       405     fire    1          0
# ...                ...       ...      ...  ...        ...
# Celesteela          25       570    steel    7          1
# Kartana            255       570    grass    7          1
# Guzzlord            15       570     dark    7          1
# Necrozma             3       600  psychic    7          1
# Magearna             3       600    steel    7          1
#
# [801 rows x 11 columns]

# %%
pokemon[(pokemon['legendary'] == 1) & (pokemon['speed'] < 50) ]
# Out:
#           deck_no  attack  defense  sp_attack  sp_defense  speed  capture_rt  \
# name
# Cosmog        789      29       31         29          31     37          45
# Cosmoem       790      29      131         29         131     37          45
# Guzzlord      799     101       53         97          53     43          15
#
#           total_bs     type  gen  legendary
# name
# Cosmog         200  psychic    7          1
# Cosmoem        400  psychic    7          1
# Guzzlord       570     dark    7          1

# %%
pokemon[pokemon['total_bs'] > 650]
# Out:
#            deck_no  attack  defense  sp_attack  sp_defense  speed  capture_rt  \
# name
# Mewtwo         150     150       70        194         120    140           3
# Tyranitar      248     164      150         95         120     71          45
# Lugia          249      90      130         90         154    110           3
# Ho             250     130       90        110         154     90           3
# Slaking        289     160      100         95          65    100          45
# Salamence      373     145      130        120          90    120          45
# Metagross      376     145      150        105         110    110           3
# Latias         380     100      120        140         150    110           3
# Latios         381     130      100        160         120    110           3
# Kyogre         382     150       90        180         160     90           3
# Groudon        383     180      160        150          90     90           3
# Rayquaza       384     180      100        180         100    115          45
# Garchomp       445     170      115        120          95     92          45
# Dialga         483     120      120        150         100     90           3
# Palkia         484     120      100        150         120    100           3
# Regigigas      486     160      110         80         110    100           3
# Giratina       487     120      100        120         100     90           3
# Arceus         493     120      120        120         120    120           3
# Reshiram       643     120      100        150         120     90           3
# Zekrom         644     150      120        120         100     90           3
# Kyurem         646     120       90        170         100     95           3
# Xerneas        716     131       95        131          98     99          45
# Yveltal        717     131       95        131          98     99          45
# Zygarde        718     100      121         91          95     85           3
# Diancie        719     160      110        160         110    110           3
# Hoopa          720     160       60        170         130     80           3
# Solgaleo       791     137      107        113          89     97          45
# Lunala         792     113       89        137         107     97          45
#
#            total_bs     type  gen  legendary
# name
# Mewtwo          780  psychic    1          1
# Tyranitar       700     rock    2          0
# Lugia           680  psychic    2          1
# Ho              680     fire    2          1
# Slaking         670   normal    3          0
# Salamence       700   dragon    3          0
# Metagross       700    steel    3          0
# Latias          700   dragon    3          1
# Latios          700   dragon    3          1
# Kyogre          770    water    3          1
# Groudon         770   ground    3          1
# Rayquaza        780   dragon    3          1
# Garchomp        700   dragon    4          0
# Dialga          680    steel    4          1
# Palkia          680    water    4          1
# Regigigas       670   normal    4          1
# Giratina        680    ghost    4          1
# Arceus          720   normal    4          1
# Reshiram        680   dragon    5          1
# Zekrom          680   dragon    5          1
# Kyurem          700   dragon    5          1
# Xerneas         680    fairy    6          1
# Yveltal         680     dark    6          1
# Zygarde         708   dragon    6          1
# Diancie         700     rock    6          1
# Hoopa           680  psychic    6          1
# Solgaleo        680  psychic    7          1
# Lunala          680  psychic    7          1

# %%
x = pokemon[((pokemon['total_bs'] > 650) | (pokemon['speed'] > 140)) & (pokemon['legendary'] == 1)]
x
# Out:
#            deck_no  attack  defense  sp_attack  sp_defense  speed  capture_rt  \
# name
# Mewtwo         150     150       70        194         120    140           3
# Lugia          249      90      130         90         154    110           3
# Ho             250     130       90        110         154     90           3
# Latias         380     100      120        140         150    110           3
# Latios         381     130      100        160         120    110           3
# Kyogre         382     150       90        180         160     90           3
# Groudon        383     180      160        150          90     90           3
# Rayquaza       384     180      100        180         100    115          45
# Deoxys         386      95       90         95          90    180           3
# Dialga         483     120      120        150         100     90           3
# Palkia         484     120      100        150         120    100           3
# Regigigas      486     160      110         80         110    100           3
# Giratina       487     120      100        120         100     90           3
# Arceus         493     120      120        120         120    120           3
# Reshiram       643     120      100        150         120     90           3
# Zekrom         644     150      120        120         100     90           3
# Kyurem         646     120       90        170         100     95           3
# Xerneas        716     131       95        131          98     99          45
# Yveltal        717     131       95        131          98     99          45
# Zygarde        718     100      121         91          95     85           3
# Diancie        719     160      110        160         110    110           3
# Hoopa          720     160       60        170         130     80           3
# Solgaleo       791     137      107        113          89     97          45
# Lunala         792     113       89        137         107     97          45
# Pheromosa      795     137       37        137          37    151         255
#
#            total_bs     type  gen  legendary
# name
# Mewtwo          780  psychic    1          1
# Lugia           680  psychic    2          1
# Ho              680     fire    2          1
# Latias          700   dragon    3          1
# Latios          700   dragon    3          1
# Kyogre          770    water    3          1
# Groudon         770   ground    3          1
# Rayquaza        780   dragon    3          1
# Deoxys          600  psychic    3          1
# Dialga          680    steel    4          1
# Palkia          680    water    4          1
# Regigigas       670   normal    4          1
# Giratina        680    ghost    4          1
# Arceus          720   normal    4          1
# Reshiram        680   dragon    5          1
# Zekrom          680   dragon    5          1
# Kyurem          700   dragon    5          1
# Xerneas         680    fairy    6          1
# Yveltal         680     dark    6          1
# Zygarde         708   dragon    6          1
# Diancie         700     rock    6          1
# Hoopa           680  psychic    6          1
# Solgaleo        680  psychic    7          1
# Lunala          680  psychic    7          1
# Pheromosa       570      bug    7          1

# %%
x.shape
# Out:
# (25, 11)

# %%
pokemon.assign(AD_total = pokemon['attack'] + pokemon['defense']).drop(columns = 'legendary').loc[: , 'attack': 'AD_total'].plot.scatter(x = 'AD_total', y='capture_rt' )
