# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/cereal.csv', index_col=0)

# %%
df
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cold        70        4    1     130   10.0
# 100% Natural Bran           Q  Cold       120        3    5      15    2.0
# All-Bran                    K  Cold        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# Almond Delight              R  Cold       110        2    2     200    1.0
# ...                        ..   ...       ...      ...  ...     ...    ...
# Triples                     G  Cold       110        2    1     250    0.0
# Trix                        G  Cold       110        1    1     140    0.0
# Wheat Chex                  R  Cold       100        3    1     230    3.0
# Wheaties                    G  Cold       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cold       110        2    1     200    1.0
#
# ...

# %%
df = pd.read_csv('../../data/candybars.csv', index_col=0)

# %%
df.to_csv("candybars-sc.csv",sep=";")

# %%
df = pd.read_csv('../../data/cereal.csv', index_col=0)

# %%
df[df['mfr'] == "Q"]

# %%
dfa = df[(df['mfr'] == "N") | (df['mfr'] == "Q")].loc[:,['mfr', 'rating']]
dfa

# %%
dfa[dfa['mfr'] == "N"]

# %%
times_six = lambda x: x * 6

# %%
df = pd.read_csv('../../data/pokemon.csv', index_col=0)

# %%
df.to_csv("pokemon-text.txt", sep=";")

# %%
pokemon = pd.read_csv('../../data/pokemon.csv', index_col=0)

# %%
mighty_pokemon = pokemon[(pokemon['defense'] > 100) & (pokemon['attack'] > 100)]

# %%
mighty_pokemon['type'].value_counts().plot.bar()

# %%
mighty_pokemon.shape

# %%
mighty_pokemon['type'].value_counts()

# %%
pokemon

# %%
pokemon[(pokemon['legendary'] == 1) & (pokemon['speed'] < 50) ]

# %%
pokemon[pokemon['total_bs'] > 650]

# %%
x = pokemon[((pokemon['total_bs'] > 650) | (pokemon['speed'] > 140)) & (pokemon['legendary'] == 1)]
x

# %%
x.shape

# %%
pokemon.assign(AD_total = pokemon['attack'] + pokemon['defense']).drop(columns = 'legendary').loc[: , 'attack': 'AD_total'].plot.scatter(x = 'AD_total', y='capture_rt' )

# %% [markdown]
# Slice the group columns from `attack` to `type` and save the new dataframe as object `pokemon`

# %%
grouped_pokemon = pokemon.groupby(by= 'type')

# %%
grouped_pokemon.mean()

# %%
df
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cold        70        4    1     130   10.0
# 100% Natural Bran           Q  Cold       120        3    5      15    2.0
# All-Bran                    K  Cold        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# Almond Delight              R  Cold       110        2    2     200    1.0
# ...                        ..   ...       ...      ...  ...     ...    ...
# Triples                     G  Cold       110        2    1     250    0.0
# Trix                        G  Cold       110        1    1     140    0.0
# Wheat Chex                  R  Cold       100        3    1     230    3.0
# Wheaties                    G  Cold       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cold       110        2    1     200    1.0
#
# ...

# %%
df['fat'] + df['protein']

# %%
df[['fat']] + df[['rating']]

# %%
from IPython.display import display

# %%
pd.set_option('display.max_rows', 10)
df
# Out:
#                           mfr  sugars
# name
# 100% Bran                   N       6
# 100% Natural Bran           Q       8
# All-Bran                    K       5
# All-Bran with Extra Fiber   K       0
# Almond Delight              R       8
# ...                        ..     ...
# Triples                     G       3
# Trix                        G      12
# Wheat Chex                  R       3
# Wheaties                    G       3
# Wheaties Honey Gold         G       8
#
# [77 rows x 2 columns]

# %%
df = df.loc[:, ['mfr', 'sugars']]
df[df['mfr'] == 'A']
# Out:
#       mfr  sugars
# name
# Maypo   A       3

# %%
df.sort_values(by='sugars', ascending=False)
# Out:
#                        mfr  sugars
# name
# Smacks                   K      15
# Golden Crisp             P      15
# Total Raisin Bran        G      14
# ...                     ..     ...
# Puffed Rice              Q       0
# Cream of Wheat (Quick)   N       0
# Shredded Wheat           N       0
#
# [77 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = df.groupby(by='mfr')['sugars'].plot(kind = 'bar',legend = True)

# %%
la = (df.groupby(by='mfr').mean().loc[:,'sugars']
                    .plot.bar(title = 'Mean sugar content among manufacturers')
)

la.set_ylabel('Sugar content (in grams)')

# %%
nutrition_plot = df.groupby(by='mfr').mean().loc[:, ['fat', 'fiber', 'protein']].plot.bar(title = "Mean nutritrion value over different manufacturers")

# %%
pokemon.groupby('type').mean().loc[:, 'attack'].sort_values(ascending=False).plot.bar(title = 'Mean sugar content among manufacturers')

# %%
df
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cold        70        4    1     130   10.0
# 100% Natural Bran           Q  Cold       120        3    5      15    2.0
# All-Bran                    K  Cold        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# Almond Delight              R  Cold       110        2    2     200    1.0
# ...                        ..   ...       ...      ...  ...     ...    ...
# Triples                     G  Cold       110        2    1     250    0.0
# Trix                        G  Cold       110        1    1     140    0.0
# Wheat Chex                  R  Cold       100        3    1     230    3.0
# Wheaties                    G  Cold       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cold       110        2    1     200    1.0
#
# ...

# %%
df.loc[df['protein'] >= 3, 'protein_new']  = 'High'

# %%
df.loc[df['protein'] < 3, 'protein_new']  = 'low'

# %%
df
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cold        70        4    1     130   10.0
# 100% Natural Bran           Q  Cold       120        3    5      15    2.0
# All-Bran                    K  Cold        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# Almond Delight              R  Cold       110        2    2     200    1.0
# ...                        ..   ...       ...      ...  ...     ...    ...
# Triples                     G  Cold       110        2    1     250    0.0
# Trix                        G  Cold       110        1    1     140    0.0
# Wheat Chex                  R  Cold       100        3    1     230    3.0
# Wheaties                    G  Cold       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cold       110        2    1     200    1.0
#
# ...

# %%
df
# Out:
#             deck_no  attack  defense  sp_attack  sp_defense  speed  \
# name
# Bulbasaur         1      49       49         65          65     45
# Ivysaur           2      62       63         80          80     60
# Venusaur          3     100      123        122         120     80
# Charmander        4      52       43         60          50     65
# Charmeleon        5      64       58         80          65     80
# ...             ...     ...      ...        ...         ...    ...
# Celesteela      797     101      103        107         101     61
# Kartana         798     181      131         59          31    109
# Guzzlord        799     101       53         97          53     43
# Necrozma        800     107      101        127          89     79
# Magearna        801      95      115        130         115     65
#
#             capture_rt  total_bs     type  gen  legendary
# name
# Bulbasaur           45       318    grass    1          0
# ...

# %%
df['total_bs'].plot.hist(bins=100)

# %%
df['total_bs'].value_counts()
# Out:
# 600    26
# 405    26
# 500    21
# 300    21
# 580    20
#        ..
# 334     1
# 478     1
# 336     1
# 338     1
# 180     1
# Name: total_bs, Length: 203, dtype: int64

# %%
df.loc[df['total_bs'] >= 500, 'base_score']  = 'strong'

# %%
df.loc[df['total_bs'] < 500, 'base_score']  = 'weak'

# %%
df['base_score'].value_counts().plot.bar()

# %%
df.to_csv('pokemon_sw.csv')

# %%
data = [[ 'apple', 'red', 'canada', True, 'round', True, 84, 100],
        ['banana', 'yellow', 'mexico', False, 'long', True, 75, 120],
        ['cantaloupe', 'orange', 'spain', True, 'round', True, 90, 1360],
        ['dragon-fruit', 'magenta', 'china', True, 'round', False, 96, 600],
        ['elderberry', 'purple', 'austria', False, 'round', True, 80, 5],
        ['fig', 'purple', 'turkey', False, 'oval', False, 78, 40],
        ['guava', 'green', 'mexico', True, 'oval', True, 83, 450],
        ['huckleberry', 'blue', 'canada', True, 'round', True, 73, 5],
        ['kiwi', 'brown', 'china', True, 'round', True, 80, 76],
        ['lemon', 'yellow', 'mexico', False, 'oval', False, 83, 65],
       ] 
  
# Create the pandas DataFrame 
fruit_salad = pd.DataFrame(data, columns = ['name', 'colour', 'location', 'seed', 'shape', 'sweetness', 'water_content', 'weight' ]) 
fruit_salad
fruit_salad.groupby(by ='shape').get_group('oval')
# Out:
#     name  colour location   seed shape  sweetness  water_content  weight
# 5    fig  purple   turkey  False  oval      False             78      40
# 6  guava   green   mexico   True  oval       True             83     450
# 9  lemon  yellow   mexico  False  oval      False             83      65

# %%
fruit_salad.groupby(by ='shape').get_group('oval')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0a5292bb81af> in <module>
# ----> 1 fruit_salad.groupby(by ='shape').get_group('oval')
#
# NameError: name 'fruit_salad' is not defined

# %%
# Out:
# name          colour
# apple         red      location          canada
#                        seed                True
#                        shape              round
#                        sweetness           True
#                        water_content         84
#                        weight               100
# banana        yellow   location          mexico
#                        seed               False
#                        shape               long
#                        sweetness           True
#                        water_content         75
#                        weight               120
# cantaloupe    orange   location           spain
#                        seed                True
#                        shape              round
#                        sweetness           True
#                        water_content         90
#                        weight              1360
# dragon-fruit  magenta  location           china
# ...

# %%
fruit_salad
# Out:
#            name   colour location   seed  shape  sweetness  water_content  \
# 0         apple      red   canada   True  round       True             84
# 1        banana   yellow   mexico  False   long       True             75
# 2    cantaloupe   orange    spain   True  round       True             90
# 3  dragon-fruit  magenta    china   True  round      False             96
# 4    elderberry   purple  austria  False  round       True             80
# 5           fig   purple   turkey  False   oval      False             78
# 6         guava    green   mexico   True   oval       True             83
# 7   huckleberry     blue   canada   True  round       True             73
# 8          kiwi    brown    china   True  round       True             80
# 9         lemon   yellow   mexico  False   oval      False             83
#
#    weight
# 0     100
# 1     120
# 2    1360
# 3     600
# 4       5
# 5      40
# 6     450
# 7       5
# 8      76
# 9      65

# %%
fruit_salad['location'] == 'canada'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: location, dtype: bool

# %%
~(fruit_salad['location'] == 'canada')
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# Name: location, dtype: bool

# %%
lego = pd.read_csv('data/lego_untidy.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-aba6d6469af5> in <module>
# ----> 1 lego = pd.read_csv('data/lego_untidy.csv', index_col=0)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
pokemon = pd.read_csv('../pokemon.csv', index_col=0)

# %%
p1 = pokemon.head(10).loc[:,['deck_no', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']]

# %%
pokemon = pd.read_csv('data/pokemon.csv', index_col=0)
p1 = pokemon.head(10).loc[:,['deck_no', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']]
p1 = (p1.assign(special_attack_defense = "a=" + p1['sp_attack'].astype(str) + ", d=" + p1['sp_attack'].astype(str))
      	.drop(columns=[ 'sp_attack', 'sp_defense'])
        .loc[:, ['deck_no', 'attack', 'defense', 'special_attack_defense', 'speed']]).reset_index()
p1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-32de215ae033> in <module>
# ----> 1 pokemon = pd.read_csv('data/pokemon.csv', index_col=0)
#       2 p1 = pokemon.head(10).loc[:,['deck_no', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']]
#       3 p1 = (p1.assign(special_attack_defense = "a=" + p1['sp_attack'].astype(str) + ", d=" + p1['sp_attack'].astype(str))
#       4         .drop(columns=[ 'sp_attack', 'sp_defense'])
#       5         .loc[:, ['deck_no', 'attack', 'defense', 'special_attack_defense', 'speed']]).reset_index()
#
# ...

# %%
pokemon = pd.read_csv('../pokemon.csv', index_col=0)

# %%
pokemon = pd.read_csv('data/pokemon.csv', index_col=0)
p2 = pokemon.loc[['Bulbasaur', 'Ivysaur', 'Ivysaur', 
                  'Venusaur', 'Charmander', 'Charmeleon', 
                  'Charmeleon', 'Charizard', 'Squirtle', 'Squirtle'], 
                ['deck_no', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']].reset_index()
p2
# Out:
#          name  deck_no  attack  defense  sp_attack  sp_defense  speed
# 0   Bulbasaur        1      49       49         65          65     45
# 1     Ivysaur        2      62       63         80          80     60
# 2     Ivysaur        2      62       63         80          80     60
# 3    Venusaur        3     100      123        122         120     80
# 4  Charmander        4      52       43         60          50     65
# 5  Charmeleon        5      64       58         80          65     80
# 6  Charmeleon        5      64       58         80          65     80
# 7   Charizard        6     104       78        159         115    100
# 8    Squirtle        7      48       65         50          64     43
# 9    Squirtle        7      48       65         50          64     43

# %%
p2
# Out:
#             deck_no  attack  defense  sp_attack  sp_defense  speed
# name
# Bulbasaur         1      49       49         65          65     45
# Ivysaur           2      62       63         80          80     60
# Ivysaur           2      62       63         80          80     60
# Venusaur          3     100      123        122         120     80
# Charmander        4      52       43         60          50     65
# Charmeleon        5      64       58         80          65     80
# Charmeleon        5      64       58         80          65     80
# Charizard         6     104       78        159         115    100
# Squirtle          7      48       65         50          64     43
# Squirtle          7      48       65         50          64     43

# %%
df = pd.read_csv('../../../data/candybars.csv', index_col=0)

# %%
df.loc[['Aero', 'Butterfinger', 'Caramilk'], ['chocolate','peanuts', 'caramel']]
# Out:
#               chocolate  peanuts  caramel
# name
# Aero                  1        0        0
# Butterfinger          1        1        1
# Caramilk              1        0        1
