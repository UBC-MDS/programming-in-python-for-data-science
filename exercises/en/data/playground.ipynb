# %%
import pandas as pd

# %%
lego_sets = pd.read_csv('lego-sets.csv', index_col=0)
lego_sets.sort_index()
# Out:
#                                              name  year  theme_id  num_parts
# set_num
# 00-1                              Weetabix Castle  1970       414        471
# 00-2                 Weetabix Promotional House 1  1976       413        147
# 00-3                 Weetabix Promotional House 2  1976       413        149
# 00-4                Weetabix Promotional Windmill  1976       413        126
# 00-6                                Special Offer  1985        67          3
# ...                                           ...   ...       ...        ...
# tominifigs-1            Town Minifig Packs 2-Pack  2000        50          2
# trucapam-1                 Captain America Mosaic  2016       598         71
# tsuper-1                        Technic Super Set  1991        12          3
# vwkit-1                            Volkswagen Kit  1959       366         22
# wwgp1-1       Wild West Limited Edition Gift Pack  1996       476          3
#
# [11673 rows x 4 columns]

# %%
lego_parts = pd.read_csv('inventory_parts.csv', index_col=0)
lego_parts
# Out:
#                  part_num  color_id  quantity is_spare
# inventory_id
# 1                48379c01        72         1        f
# 1                   48395         7         1        f
# 1                mcsport6        25         1        f
# 1                  paddle         0         1        f
# 3             11816pr0005        78         1        f
# ...                   ...       ...       ...      ...
# 18708               99206         0         3        f
# 18708               99207        71         4        f
# 18708               99780        15         4        f
# 18708               99780         0         9        f
# 18708               99780        72         5        f
#
# [580251 rows x 4 columns]

# %%
lego_inventory = pd.read_csv('inventories.csv', index_col=0)
lego_inventory
# Out:
#        version   set_num
# id
# 1            1    7922-1
# 3            1    3931-1
# 4            1    6942-1
# 15           1    5158-1
# 16           1     903-1
# ...        ...       ...
# 18593        1   31066-1
# 18645        1   71018-7
# 18701        1  71018-17
# 18704        1   60159-1
# 18708        1   75090-2
#
# [11681 rows x 2 columns]

# %%
lego_color= pd.read_csv('colors.csv', index_col=0)
lego_color
# Out:
#                                name     rgb is_trans
# id
# -1                          Unknown  0033B2        f
#  0                            Black  05131D        f
#  1                             Blue  0055BF        f
#  2                            Green  237841        f
#  3                   Dark Turquoise  008F9B        f
# ...                             ...     ...      ...
#  1004  Trans Flame Yellowish Orange  FCB76D        t
#  1005             Trans Fire Yellow  FBE890        t
#  1006        Trans Light Royal Blue  B4D4F7        t
#  1007                 Reddish Lilac  8E5597        f
#  9999                    [No Color]  05131D        f
#
# [135 rows x 3 columns]

# %%
parts_colour = lego_parts.merge(lego_color, left_on='color_id', right_index=True)

# %%
parts_colour
# Out:
#               part_num  color_id  quantity is_spare                    name  \
# inventory_id
# 1             48379c01        72         1        f        Dark Bluish Gray
# 22               15573        72         1        f        Dark Bluish Gray
# 22                2654        72         4        f        Dark Bluish Gray
# 22               3070b        72         1        f        Dark Bluish Gray
# 22               3070b        72         1        t        Dark Bluish Gray
# ...                ...       ...       ...      ...                     ...
# 10904             4133       351         2        f        Medium Dark Pink
# 10904             4728       351         4        f        Medium Dark Pink
# 12090             6180      1001         1        f           Medium Violet
# 13140             3001      1001         1        f           Medium Violet
# 16084            51686      1006         2        f  Trans Light Royal Blue
#
#                  rgb is_trans
# inventory_id
# 1             6C6E68        f
# 22            6C6E68        f
# 22            6C6E68        f
# 22            6C6E68        f
# 22            6C6E68        f
# ...              ...      ...
# 10904         F785B1        f
# 10904         F785B1        f
# 12090         9391E4        f
# 13140         9391E4        f
# 16084         B4D4F7        t
#
# [580251 rows x 7 columns]

# %%
p_c_i = parts_colour.merge(lego_inventory, left_index=True, right_index=True)
p_c_i
# Out:
#        part_num  color_id  quantity is_spare                name     rgb  \
# 1      48379c01        72         1        f    Dark Bluish Gray  6C6E68
# 1         48395         7         1        f          Light Gray  9BA19D
# 1      mcsport6        25         1        f              Orange  FE8A18
# 1        paddle         0         1        f               Black  05131D
# 3         92258         0         1        f               Black  05131D
# ...         ...       ...       ...      ...                 ...     ...
# 18708     51739       288         2        f          Dark Green  184632
# 18708     54200       288         2        f          Dark Green  184632
# 18708     93606       288         1        f          Dark Green  184632
# 18708     20243      9999         1        f          [No Color]  05131D
# 18708      6141        35         6        f  Trans-Bright Green  D9E4A7
#
#       is_trans  version  set_num
# 1            f        1   7922-1
# 1            f        1   7922-1
# 1            f        1   7922-1
# 1            f        1   7922-1
# 3            f        1   3931-1
# ...        ...      ...      ...
# 18708        f        1  75090-2
# 18708        f        1  75090-2
# 18708        f        1  75090-2
# 18708        f        1  75090-2
# 18708        t        1  75090-2
#
# [580251 rows x 9 columns]

# %%
pcim = p_c_i.merge(lego_sets, left_on='set_num', right_index=True, how='outer')

# %%
pcim
# Out:
#        set_num                                             name_y  year  \
# 1.0     7922-1  McDonald's Sports Set Number 6 - Orange Vest S...  2004
# 1.0     7922-1  McDonald's Sports Set Number 6 - Orange Vest S...  2004
# 1.0     7922-1  McDonald's Sports Set Number 6 - Orange Vest S...  2004
# 1.0     7922-1  McDonald's Sports Set Number 6 - Orange Vest S...  2004
# 3.0     3931-1                                 Emma's Splash Pool  2012
# ..         ...                                                ...   ...
# NaN       VP-7                   Fire Value Pack (6554 6407 6564)  1997
# NaN       VP-8                 Star Wars Co-Pack of 7130 and 7150  2000
# NaN     W098-1                            Watch Set, Classic Blue  2006
# NaN  W991526-1  Homeschool Introduction to Simple and Motorize...  2009
# NaN    wwgp1-1                Wild West Limited Edition Gift Pack  1996
#
#      theme_id  num_parts is_trans  part_num  quantity
# 1.0       460          4        f  48379c01       1.0
# 1.0       460          4        f     48395       1.0
# 1.0       460          4        f  mcsport6       1.0
# 1.0       460          4        f    paddle       1.0
# 3.0       494         43        f     92258       1.0
# ..        ...        ...      ...       ...       ...
# NaN        98          3      NaN       NaN       NaN
# NaN       169          2      NaN       NaN       NaN
# NaN       501          0      NaN       NaN       NaN
# NaN       529          0      NaN       NaN       NaN
# NaN       476          3      NaN       NaN       NaN
#
# [581211 rows x 8 columns]

# %%
pcim = pcim.loc[: , ['set_num','name_y','year', 'theme_id', 'num_parts', 'is_trans', 'part_num', 'quantity']]

# %%
pcim.groupby(['set_num']).ngroups
group.groupby(['set_num']).ngroups
# Out:
# 11673

# %%
group = pcim.fillna(-1).groupby(['set_num', 'is_trans']).sum().sort_index()
group
# Out:
#                        year  theme_id  num_parts  quantity
# set_num    is_trans
# 00-1       f         100470     21114      24021     471.0
# 00-2       f          88920     18585       6615     143.0
#            t           3952       826        294       4.0
# 00-3       f          84968     17759       6407     149.0
# 00-4       f          96824     20237       6174     126.0
# ...                     ...       ...        ...       ...
# trucapam-1 f          44352     13156       1562      71.0
# tsuper-1   -1          1991        12          3      -1.0
# vwkit-1    f          17631      3294        198      20.0
#            t           1959       366         22       2.0
# wwgp1-1    -1          1996       476          3      -1.0
#
# [18129 rows x 4 columns]

# %%
adding = group.loc[:,['quantity']].reset_index()

adding.loc[adding['is_trans'] == 'f', 'is_trans'] = 'matte'
adding.loc[adding['is_trans'] == 't', 'is_trans'] = 'transparent'
additional = (adding.pivot(index='set_num',
                           columns='is_trans',
                           values='quantity'))
            
additional = additional.loc[:,'matte':'transparent' ]

# %%
adding
# Out:
#           set_num     is_trans  quantity
# 0            00-1        matte     471.0
# 1            00-2        matte     143.0
# 2            00-2  transparent       4.0
# 3            00-3        matte     149.0
# 4            00-4        matte     126.0
# ...           ...          ...       ...
# 18124  trucapam-1        matte      71.0
# 18125    tsuper-1           -1      -1.0
# 18126     vwkit-1        matte      20.0
# 18127     vwkit-1  transparent       2.0
# 18128     wwgp1-1           -1      -1.0
#
# [18129 rows x 3 columns]

# %%
additional = additional.fillna(value=0)

# %%
additional
# Out:
# is_trans      matte  transparent
# set_num
# 00-1          471.0          0.0
# 00-2          143.0          4.0
# 00-3          149.0          0.0
# 00-4          126.0          0.0
# 00-6            0.0          0.0
# ...             ...          ...
# tominifigs-1    0.0          0.0
# trucapam-1     71.0          0.0
# tsuper-1        0.0          0.0
# vwkit-1        20.0          2.0
# wwgp1-1         0.0          0.0
#
# [11673 rows x 2 columns]

# %%
export = lego_sets.merge(additional, left_index=True, right_index=True)
export
# Out:
#                                                             name  year  \
# set_num
# 00-1                                             Weetabix Castle  1970
# 0011-2                                         Town Mini-Figures  1978
# 0011-3                                Castle 2 for 1 Bonus Offer  1987
# 0012-1                                        Space Mini-Figures  1979
# 0013-1                                        Space Mini-Figures  1979
# ...                                                          ...   ...
# Wauwatosa-1    LEGO Store Grand Opening Exclusive Set, Mayfai...  2012
# WHITEHOUSE-1                                   Micro White House  2015
# Wiesbaden-1    LEGO Store Grand Opening Exclusive Set, Wiesba...  2010
# WishingWell-1                     Wishing Well [Toys R Us Promo]  2013
# wwgp1-1                      Wild West Limited Edition Gift Pack  1996
#
#                theme_id  num_parts  matte  transparent
# set_num
# 00-1                414        471  471.0          0.0
# 0011-2               84         12   12.0          0.0
# 0011-3              199          2    0.0          0.0
# 0012-1              143         12   12.0          0.0
# 0013-1              143         12   12.0          0.0
# ...                 ...        ...    ...          ...
# Wauwatosa-1         408         15   15.0          0.0
# WHITEHOUSE-1        598         59   59.0          0.0
# Wiesbaden-1         408        146  148.0          0.0
# WishingWell-1       494         28   28.0          0.0
# wwgp1-1             476          3    0.0          0.0
#
# [11673 rows x 6 columns]

# %%
export.to_csv('lego_untidy2.csv')

# %%
lego = pd.read_csv('lego-sets.csv', index_col=0)
lego
# Out:
#                                                             name  year  \
# set_num
# 00-1                                             Weetabix Castle  1970
# 0011-2                                         Town Mini-Figures  1978
# 0011-3                                Castle 2 for 1 Bonus Offer  1987
# 0012-1                                        Space Mini-Figures  1979
# 0013-1                                        Space Mini-Figures  1979
# ...                                                          ...   ...
# Wauwatosa-1    LEGO Store Grand Opening Exclusive Set, Mayfai...  2012
# WHITEHOUSE-1                                   Micro White House  2015
# Wiesbaden-1    LEGO Store Grand Opening Exclusive Set, Wiesba...  2010
# WishingWell-1                     Wishing Well [Toys R Us Promo]  2013
# wwgp1-1                      Wild West Limited Edition Gift Pack  1996
#
#                theme_id  num_parts
# set_num
# 00-1                414        471
# 0011-2               84         12
# 0011-3              199          2
# 0012-1              143         12
# 0013-1              143         12
# ...                 ...        ...
# Wauwatosa-1         408         15
# WHITEHOUSE-1        598         59
# Wiesbaden-1         408        146
# WishingWell-1       494         28
# wwgp1-1             476          3
#
# [11673 rows x 4 columns]

# %%
new = (lego.reset_index()
     .melt(id_vars=['set_num','name', 'year'], 
           value_vars=['theme_id', 'num_parts'],
           var_name="lego_info",
           value_name="value")
     .sort_values('set_num').set_index('set_num')
     
)

# %%
new
# Out:
#                                          name  year  lego_info  value
# set_num
# 00-1                          Weetabix Castle  1970   theme_id    414
# 00-1                          Weetabix Castle  1970  num_parts    471
# 00-2             Weetabix Promotional House 1  1976  num_parts    147
# 00-2             Weetabix Promotional House 1  1976   theme_id    413
# 00-3             Weetabix Promotional House 2  1976  num_parts    149
# ...                                       ...   ...        ...    ...
# tsuper-1                    Technic Super Set  1991   theme_id     12
# vwkit-1                        Volkswagen Kit  1959  num_parts     22
# vwkit-1                        Volkswagen Kit  1959   theme_id    366
# wwgp1-1   Wild West Limited Edition Gift Pack  1996   theme_id    476
# wwgp1-1   Wild West Limited Edition Gift Pack  1996  num_parts      3
#
# [23346 rows x 4 columns]

# %%
new.to_csv('lego_untidy.csv')
